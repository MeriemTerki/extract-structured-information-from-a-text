# %% [markdown]
# <a href="https://colab.research.google.com/github/MeriemTerki/extract-structured-information-from-a-text/blob/main/extract_structured_information_from_a_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

with open('/content/drive/MyDrive/DeepLearningProjects/Information Extraction/register.txt', 'r') as f:
    text = [line for line in f.readlines()]

# %%
df = pd.DataFrame(text,columns=['text'])
df.head()
# Out:
#                                                 text
# 0  On August 21 1826 a son was born to John Bon a...
# 1  On June 11 1813 a daughter was born to James D...
# 2  On January 1 1832 a son was born to his father...

# %%
from spacy.matcher import Matcher 
import spacy

# %%
import en_core_web_sm

text = df['text'][0]

nlp = en_core_web_sm.load()
doc = nlp(text)

# %%
features = []
for token in doc:
    features.append({'token' : token.text, 'pos' : token.pos_})
fdf = pd.DataFrame(features)
fdf.head(len(fdf))
# Out:
#       token    pos
# 0        On    ADP
# 1    August  PROPN
# 2        21    NUM
# 3      1826    NUM
# 4         a    DET
# 5       son   NOUN
# 6       was    AUX
# 7      born   VERB
# 8        to    ADP
# 9      John  PROPN
# 10      Bon  PROPN
# 11      and  CCONJ
# 12    named   VERB
# 13      him   PRON
# 14  Francis  PROPN
# 15        .  PUNCT
# 16       \n  SPACE

# %% [markdown]
# ## Extract Father

# %%
first_tokens = ['to', 'father']
last_tokens = ['and', 'naming']
pattern_father = [[{'LOWER' : {'IN' : first_tokens}},
           {'POS':'PROPN', 'OP' : '+'},
           {'LOWER': {'IN' : last_tokens}} ]]

# %%
def get_father(x):
    nlp = en_core_web_sm.load()
    doc = nlp(x)
    matcher = Matcher(nlp.vocab) 
    matcher.add("matching_father", pattern_father) 

    matches = matcher(doc)
    sub_text = ''    
    if(len(matches) > 0):
        span = doc[matches[0][1]:matches[0][2]] 
        sub_text = span.text
    tokens = sub_text.split(' ')
    
    name, surname = tokens[1:-1]
    return name, surname

# %%
new_columns = ['father name','surname']
for n,col in enumerate(new_columns):
    df[col] = df['text'].apply(lambda x: get_father(x)).apply(lambda x: x[n])

# %%
df
# Out:
#                                                 text father name surname
# 0  On August 21 1826 a son was born to John Bon a...        John     Bon
# 1  On June 11 1813 a daughter was born to James D...       James   Donne
# 2  On January 1 1832 a son was born to his father...       David   Borne

# %% [markdown]
# ## Extract Child

# %%
first_tokens = ['him', 'her']
last_tokens = ['.']
pattern_son = [[{'LOWER' : {'IN' : first_tokens}},
           {'POS':'PROPN', 'OP' : '+'},
           {'LOWER': {'IN' : last_tokens}} ]]

# %%
def get_child(x):
    nlp = en_core_web_sm.load()
    doc = nlp(x)
    matcher = Matcher(nlp.vocab) 
    matcher.add("matching_son", pattern_son) 

    matches = matcher(doc)
    sub_text = ''    
    if(len(matches) > 0):
        span = doc[matches[0][1]:matches[0][2]] 
        sub_text = span.text
    # remove punct
    sub_text = sub_text[:-1]
    tokens = sub_text.split(' ')
    
    return ' '.join(tokens[1:])

# %%
df['child'] = df['text'].apply(lambda x: get_child(x))

# %%
df
# Out:
#                                                 text father name surname  \
# 0  On August 21 1826 a son was born to John Bon a...        John     Bon
# 1  On June 11 1813 a daughter was born to James D...       James   Donne
# 2  On January 1 1832 a son was born to his father...       David   Borne
#
#         child
# 0     Francis
# 1  Mary Sarah
# 2        John

# %% [markdown]
# ## Extract Birth Date

# %%
def get_date(x):
    months={"January":"01","February":"02","March":"03","April":"04","May":"05","June":"06",
            "July":"07","August":"08","September":"09","October":"10","November":"11","December":"12",}
    tokens = x.split(" ")
    # month
    month = months[tokens[1]]
    # day
    day=tokens[2]
    if(len(day)==1):
        day="0"+day
    
    # year
    year = x.split(" ")[3]
    
    return (year+"-"+month+"-"+day)

# %%
df['date'] = df['text'].apply(lambda x: get_date(x))

# %%
df
# Out:
#                                                 text father name surname  \
# 0  On August 21 1826 a son was born to John Bon a...        John     Bon
# 1  On June 11 1813 a daughter was born to James D...       James   Donne
# 2  On January 1 1832 a son was born to his father...       David   Borne
#
#         child        date
# 0     Francis  1826-08-21
# 1  Mary Sarah  1813-06-11
# 2        John  1832-01-01

# %% [markdown]
# ## Extract Gender

# %%
def get_gender(x):
    if 'son' in x:
        return 'M'
    return 'F'

# %%
df['gender'] = df['text'].apply(lambda x: get_gender(x))

# %%
df
# Out:
#                                                 text father name surname  \
# 0  On August 21 1826 a son was born to John Bon a...        John     Bon
# 1  On June 11 1813 a daughter was born to James D...       James   Donne
# 2  On January 1 1832 a son was born to his father...       David   Borne
#
#         child        date gender
# 0     Francis  1826-08-21      M
# 1  Mary Sarah  1813-06-11      F
# 2        John  1832-01-01      M

# %%
df.to_csv('structured_register.csv')
